# %%
# !pip install datasets
# !pip install umap-learn plotly

# %%
import sys

from datasets import Dataset, DatasetDict
import numpy as np
import pandas as pd
import torch
from transformers import AutoTokenizer, EsmForSequenceClassification, logging, \
    Trainer, TrainingArguments
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load Model

# %%
tokenizer = AutoTokenizer.from_pretrained("facebook/esm2_t6_8M_UR50D")
model = EsmForSequenceClassification.from_pretrained("facebook/esm2_t6_8M_UR50D")
# Out:
# Some weights of EsmForSequenceClassification were not initialized from the model checkpoint at facebook/esm2_t6_8M_UR50D and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Load Dataset

# %%
sep = '0'
df = pd.read_csv('train-set_full-seq.csv')

# %% [markdown]
# ### Filter Dataset

# %%
from collections import Counter
ept = Counter(df['epitope_aa']).most_common()[0][0]
# ept = 'AYAQKIFKI'
ept
# Out:
# 'KLGGALQAK'

# %%
epitope_df = df[df.epitope_aa == ept]
epitope_df = pd.DataFrame({'seq': epitope_df['cdr3_beta_aa'], 'label': epitope_df['label_true_pair']})
# epitope_df = pd.DataFrame({'seq': epitope_df['cdr3_alpha_aa'] + sep + epitope_df['epitope_aa']+ sep + epitope_df['cdr3_beta_aa'], 'label': epitope_df['label_true_pair']})
epitope_df
# Out:
#                      seq  label
# 3271  CASGYWKLAGGPQETQYF   True
# 3272    CASSLYGNLGTGELFF   True
# 3273   CASSRGGIASGANVLTF   True
# 3274      CASSQGTVLQPQHF   True
# 3275      CARQPLRGANVLTF   True
# ...                  ...    ...
# 7184    CASSLSTHESYNEQFF  False
# 7185     CASTPIESSTDTQYF  False
# 7186       CASSQDPPDTQYF  False
# 7187       CASRGGLGTEAFF  False
# 7188    CASSIAPSGVAYEQYF  False
#
# [3918 rows x 2 columns]

# %%
epitope_dataset = Dataset.from_pandas(epitope_df)
epitope_dataset
# Out:
# Dataset({
#     features: ['seq', 'label', '__index_level_0__'],
#     num_rows: 3918
# })

# %%
def tokenize_function(dataset):
    return tokenizer(dataset['seq'], return_tensors='pt', max_length=len(tokenizer), padding='max_length', truncation=True)
epitope_tokenized_dataset = epitope_dataset.map(tokenize_function, batched=True, batch_size=16).with_format('torch')
epitope_tokenized_dataset
# Out:
# Map:   0%|          | 0/3918 [00:00<?, ? examples/s]
# Dataset({
#     features: ['seq', 'label', '__index_level_0__', 'input_ids', 'attention_mask'],
#     num_rows: 3918
# })

# %%
inputs = {
    'input_ids': epitope_tokenized_dataset['input_ids'],
    'attention_mask': epitope_tokenized_dataset['attention_mask']
}

with torch.no_grad():
    output = model(**inputs, output_hidden_states=True)

# %%
logits = output.logits
preds = logits.argmax(dim=1)
preds
# Out:
# tensor([1, 1, 1,  ..., 1, 1, 1])

# %%
logits.argmax(dim=1).unique(return_counts=True)
# Out:
# (tensor([0, 1]), tensor([  58, 3860]))

# %%
cls_tokens = output.hidden_states[-1][:,0,:]
cls_tokens.shape
# Out:
# torch.Size([3918, 320])

# %% [markdown]
# ### Visualization

# %%
import plotly.express as px
from umap import UMAP
from sklearn.manifold import TSNE

# %%
cls_tokens.shape
# Out:
# torch.Size([3918, 320])

# %%
epitope_df
# Out:
#                      seq  label
# 3271  CASGYWKLAGGPQETQYF   True
# 3272    CASSLYGNLGTGELFF   True
# 3273   CASSRGGIASGANVLTF   True
# 3274      CASSQGTVLQPQHF   True
# 3275      CARQPLRGANVLTF   True
# ...                  ...    ...
# 7184    CASSLSTHESYNEQFF  False
# 7185     CASTPIESSTDTQYF  False
# 7186       CASSQDPPDTQYF  False
# 7187       CASRGGLGTEAFF  False
# 7188    CASSIAPSGVAYEQYF  False
#
# [3918 rows x 2 columns]

# %%
umap_2d = UMAP(n_components=2, init='random', random_state=0)
umap_3d = UMAP(n_components=3, init='random', random_state=0)
tsne_2d = TSNE(n_components=2)

# %%
umap_proj_2d = umap_2d.fit_transform(cls_tokens)
umap_proj_3d = umap_3d.fit_transform(cls_tokens)
tsne_proj_2d = tsne_2d.fit_transform(cls_tokens)
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1943: UserWarning:
#
# n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1943: UserWarning:
#
# n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
fig = px.scatter(umap_proj_2d, x=0, y=1, color=epitope_df.label)
fig.update_traces(marker={'size': 3})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="96566863-a832-46fd-aa4c-880d88c9ad5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96566863-a832-46fd-aa4c-880d88c9ad5d")) {                    Plotly.newPlot(                        "96566863-a832-46fd-aa4c-880d88c9ad5d",                        [{"hovertemplate":"color=True\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"True","showlegend":true,"x":[6.389493942260742,3.6990981101989746,4.657237529754639,-0.23331278562545776,0.6462575793266296,2.7561776638031006,7.7070207595825195,6.870692253112793,3.3591649532318115,2.437103748321533,7.073850631713867,4.595137119293213,4.653483867645264,5.6180901527404785,7.466285228729248,2.176380157470703,5.7125325202941895,0.4881713390350342,1.9829756021499634,0.023724857717752457,5.466391086578369,5.4414448738098145,5.637999057769775,5.9448161125183105,5.53663969039917,4.745357036590576,4.494828224182129,2.335345983505249,2.5194342136383057,3.613868236541748,6.379909515380859,7.035053730010986,3.4183990955352783,7.993873596191406,8.055274963378906,2.8543426990509033,3.118844747543335,2.959186553955078,5.048293590545654,-0.3874647319316864,1.0848604440689087,3.6810030937194824,1.3202234506607056,6.221346378326416,7.369385719299316,3.7407498359680176,5.137458324432373,6.417838096618652,5.544108867645264,5.871556758880615,6.208152770996094,5.202710151672363,2.8515920639038086,3.729060173034668,-0.25903770327568054,1.271438717842102,2.8168911933898926,-0.5412518978118896,4.337914943695068,1.541698932647705,6.234608173370361,7.713687419891357,2.8897244930267334,5.85666036605835,3.1297476291656494,9.270228385925293,1.2624489068984985,3.7971794605255127,-0.7955397367477417,6.111367225646973,3.5514605045318604,5.762615203857422,5.992444038391113,4.139636039733887,2.473130941390991,6.9243879318237305,5.5657501220703125,3.48359751701355,3.892528772354126,6.269623756408691,2.2343833446502686,6.469958305358887,5.43139123916626,2.4334616661071777,2.483851671218872,3.7932798862457275,6.744874000549316,4.476701259613037,1.020415186882019,-1.393822193145752,0.816739559173584,-1.4188212156295776,6.497866153717041,8.593302726745605,4.646739959716797,2.7373263835906982,-1.0223686695098877,1.6024723052978516,6.02244234085083,6.010720729827881,2.2542829513549805,3.6481690406799316,8.477062225341797,4.0443196296691895,2.211482524871826,3.5809879302978516,3.3255319595336914,3.2637782096862793,5.369448184967041,7.980621337890625,6.451864719390869,1.5367472171783447,7.119555950164795,8.627628326416016,2.8566675186157227,7.166734218597412,8.111810684204102,4.85391902923584,-1.4378182888031006,2.4988579750061035,3.7729265689849854,3.441483974456787,0.22184337675571442,1.0295710563659668,4.683509349822998,5.1435627937316895,2.73679256439209,6.680423259735107,6.7711896896362305,5.074992656707764,4.896640300750732,2.6611790657043457,-0.8379800319671631,6.771188735961914,4.9862565994262695,2.839193344116211,3.5073976516723633,4.5622429847717285,3.605654716491699,5.924894332885742,5.295284271240234,2.829240083694458,3.165174961090088,6.777795791625977,2.793353796005249,5.909971714019775,4.0833539962768555,7.790015697479248,7.536901950836182,8.400543212890625,4.696084976196289,7.721991539001465,2.9797632694244385,-3.273902416229248,0.823734700679779,1.263365626335144,0.9862728118896484,3.2292280197143555,4.887407302856445,3.174941301345825,4.349560737609863,5.678523540496826,5.812543869018555,3.9638729095458984,2.6507859230041504,2.948131799697876,3.686640501022339,4.62578821182251,3.280411720275879,5.008512020111084,6.2426958084106445,2.7663278579711914,3.411639928817749,3.135 ...

# %%
fig = px.scatter_3d(umap_proj_3d, x=0, y=1, z=2, color=epitope_df.label)
fig.update_traces(marker={'size': 3})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="322b8736-223a-4479-9d26-2a3677048a92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("322b8736-223a-4479-9d26-2a3677048a92")) {                    Plotly.newPlot(                        "322b8736-223a-4479-9d26-2a3677048a92",                        [{"hovertemplate":"color=True\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"True","scene":"scene","showlegend":true,"x":[3.634965419769287,4.116252899169922,6.8243408203125,5.321218490600586,7.4567365646362305,6.94559383392334,3.4372823238372803,5.501002788543701,5.053525924682617,5.527795791625977,4.570821762084961,3.246285915374756,6.767366409301758,4.462038040161133,3.338222026824951,4.280937194824219,3.4745450019836426,6.877865791320801,4.139652729034424,5.416905403137207,3.8725838661193848,4.995301723480225,4.260502815246582,3.699798345565796,5.868762016296387,6.685872554779053,6.826617240905762,7.356522560119629,7.506504058837891,3.1515257358551025,3.479330062866211,4.028051376342773,4.032809734344482,2.9905595779418945,3.3207383155822754,4.635578632354736,7.386301517486572,6.045098304748535,3.2227437496185303,5.573598861694336,6.700064659118652,5.4708571434021,6.282222747802734,3.118197202682495,4.2006001472473145,5.763506889343262,3.3070015907287598,6.148519039154053,3.262836456298828,4.211556434631348,2.977289915084839,4.2371344566345215,7.056213855743408,4.501578330993652,5.220890998840332,6.308229446411133,5.161952495574951,5.750244617462158,4.4813055992126465,5.895068168640137,2.4258594512939453,3.4350645542144775,5.498227119445801,3.760793685913086,7.394804000854492,4.131610870361328,7.430741786956787,5.699604034423828,5.79401159286499,4.239466190338135,4.382392883300781,4.272520542144775,4.324395656585693,3.592193841934204,6.368021488189697,4.643445014953613,6.124295234680176,5.631062030792236,3.453537702560425,3.6885335445404053,5.397634983062744,3.3319621086120605,3.93629789352417,7.827205181121826,6.7651143074035645,5.949969291687012,4.350584983825684,4.879120349884033,6.732670307159424,5.727574825286865,6.352996349334717,5.745044231414795,5.7490692138671875,3.491248369216919,3.8550467491149902,3.5923945903778076,5.273211479187012,7.5574164390563965,3.325037717819214,3.7247042655944824,4.201200485229492,5.278219699859619,3.204580307006836,5.1423845291137695,4.637512683868408,4.055816173553467,6.256457805633545,7.165586948394775,4.363733768463135,3.273608446121216,2.787569999694824,7.372420787811279,3.4412593841552734,3.3050005435943604,4.828783988952637,4.343381404876709,3.225362539291382,2.946657180786133,5.76623010635376,7.795699119567871,6.835780143737793,3.6075644493103027,7.599936485290527,7.2861785888671875,3.812624931335449,3.7086591720581055,7.058045387268066,5.835560321807861,3.497049570083618,6.042449951171875,5.463377952575684,7.6738762855529785,5.998565673828125,4.61262845993042,4.190905570983887,7.748086452484131,5.2183427810668945,4.934159755706787,6.229714393615723,3.5665104389190674,4.934135437011719,5.763489246368408,5.546672821044922,5.534371376037598,4.803430080413818,3.1819777488708496,6.453731536865234,3.2863142490386963,3.1690499782562256,3.62699031829834,4.794004440307617,4.113140106201172,4.057873725891113,10.929176330566406,7.006013870239258,7.53111457824707,6.646306991577148,6.597397804260254,4.7987494468688965,3.9375007152557373,4.704352378845215,5.350358009338379,3.1027677059173584,7.412816524505615,7.438939094543457,6.388930320739746,5.586751461029053,4.207376480102539,7.333361625671387,2.9638967514038086,4.0484395027160645,5.72745418548584,6.488193511962891,4.006185054779053 ...

# %%
fig = px.scatter(tsne_proj_2d, x=0, y=1, color=epitope_df.label)
fig.update_traces(marker={'size': 3})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c034718c-43d2-4b4f-9570-ae738c5cb911" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c034718c-43d2-4b4f-9570-ae738c5cb911")) {                    Plotly.newPlot(                        "c034718c-43d2-4b4f-9570-ae738c5cb911",                        [{"hovertemplate":"color=True\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"True","showlegend":true,"x":[13.019969940185547,-8.385882377624512,-30.967042922973633,-14.943938255310059,-33.31807327270508,-37.908084869384766,56.80107116699219,-10.620794296264648,-2.2735214233398438,-8.24208927154541,36.43421173095703,34.40864181518555,-29.51412010192871,0.9447559714317322,27.160263061523438,17.418392181396484,26.966413497924805,-0.6334945559501648,17.409500122070312,-21.40753746032715,27.57828712463379,-5.454051494598389,-1.8559401035308838,47.50337219238281,-11.991775512695312,-28.474483489990234,-30.738035202026367,-43.75381088256836,-51.125946044921875,27.060033798217773,12.106218338012695,19.661001205444336,15.938408851623535,47.94923782348633,49.27332305908203,8.06567096710205,-43.17171096801758,-12.637243270874023,37.25996398925781,-21.74850082397461,-31.829660415649414,-28.939117431640625,1.1352907419204712,25.27182960510254,33.04610061645508,-22.775598526000977,18.94904327392578,-45.2411003112793,41.39353561401367,3.476853609085083,20.864990234375,0.7522995471954346,-36.003753662109375,10.466032981872559,-22.48069953918457,-27.879375457763672,-9.587553977966309,-26.533748626708984,0.9135677218437195,3.2049670219421387,34.377906799316406,26.59250259399414,-14.922344207763672,47.146183013916016,-47.66670227050781,34.38229751586914,-54.07817459106445,-0.8281136751174927,-28.831754684448242,7.912191867828369,3.9181902408599854,1.0214381217956543,-14.361845016479492,18.512401580810547,-22.10875129699707,40.994384765625,-14.398786544799805,-17.589902877807617,22.219409942626953,9.430837631225586,-10.296588897705078,43.92888641357422,5.500167369842529,-54.7122917175293,-18.563735961914062,-29.82286262512207,42.63107681274414,1.3151792287826538,-29.923538208007812,-38.065711975097656,-26.908580780029297,-37.39827346801758,-16.062759399414062,31.075515747070312,28.3709659576416,33.72862243652344,-32.183990478515625,-48.3011360168457,49.1878547668457,46.897674560546875,13.54987907409668,2.6604318618774414,39.07084655761719,6.832731246948242,5.357523441314697,10.483128547668457,-37.282161712646484,-48.077667236328125,-8.396187782287598,52.21012878417969,22.345256805419922,-48.36595916748047,40.99365234375,37.05825424194336,-2.248720407485962,-2.1521477699279785,48.805789947509766,31.677682876586914,-39.996421813964844,-55.21733093261719,-41.30338668823242,9.910555839538574,-32.469295501708984,-40.35020446777344,15.426922798156738,12.798012733459473,-39.667457580566406,-14.48267650604248,33.90011978149414,-29.122360229492188,-15.965485572814941,-53.0506477355957,-34.58548355102539,-7.685564041137695,-3.289947509765625,-54.722389221191406,-15.233566284179688,-0.30963653326034546,-27.232845306396484,56.73683547973633,-9.08236026763916,-13.504918098449707,-8.84105396270752,-12.196870803833008,-1.3310133218765259,13.930780410766602,-36.46845245361328,44.850059509277344,41.93232345581055,24.669347763061523,-5.843409061431885,18.20187759399414,7.565847396850586,19.244600296020508,-33.15896987915039,-52.39749526977539,-28.761686325073242,-32.64114761352539,-6.0406060218811035,7.965605735778809,-0.279668927192688,15.174322128295898,26.683807373046875,-48.089805603027344,-50.71062088012695,-23.004838943481445,4.96139669418335,10.834988594055176,-46.0825843 ...
